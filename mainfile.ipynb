# %%
from adminpanel import *
from user import *
import sys
ad=AdminPanel()
us=User()
while True:
    
    print("Press 1 for Admin Login")
    print("Press 2 for User Login")
    print("Press 3 for Exit")
    option = int(input("Enter your option:"))
    if option==1:
        print("***************************Admin Login***************************")
        username = input("Enter your username:")
        password = input("Enter your password:")
        temp = ad.admin_login(username,password)
        if temp:
                print("Press 1 for Add New Bouquet")
                print("Press 2 for View Bouquet List")
                print("Press 3 for Edit Bouquet List")
                print("Press 4 for Remove Bouquet List")
                choose=int(input("Enter your choice:"))
                if choose ==1:
                    print(ad.add_new_bouquet())
                    print(ad.add_new_bouquet())
                    print(ad.add_new_bouquet())
                    print("New Bouquet List Added Successfully!")
                    print("*"*70)
                if choose ==2:
                    print(ad.view_bouquet_details())
                    print("You have viewed your bouquet list!")
                    print("*"*70)
                if choose ==3:
                    print(ad.edit_bouquet_details())
                    print("You haved edited your bouquet list successfully!")
                    print("*"*70)
                if choose ==4:
                    print(ad.remove_bouquet_details())
                    print("Bouquet List removed successfully!")
                    print("*"*70)
    elif option==2:
        print("***************************User SignUp***************************")
        print("Press R for Registration")       
        print("Press L for Login")               
        print("Press U for Update profile")
        print("*"*70)
        choice=input("Enter your choice:").upper()
        if choice=="R":
            print(us.registration())
            print("Registration Successfull!")
            print("*"*70)
        elif choice =="L":
            print(us.log_in())
            print("Press P for Place New Order")
            print("Press O for Order History")
            print("*"*70)
            op=input("Choose your option:").upper()
            if op=="P":
                print("Choose 1 for Orchid Hand Bunch - Rs.300")
                print("Choose 2 for Roses - Rs.350")
                print("Choose 3 for Bunch of mixed roses - Rs.375")
                print("Choose 4 for Double Layered Gerbera - Rs.400")
                print("Choose 5 for Yellow rose hunch - Rs.510")
                print("Choose 6 for Rose vase - Rs.540")
                print("Choose 7 for Roses and Gerberas - Rs.765")
                print("Choose 8 for Red and yellow roses - Rs.1190")
                print("Choose 9 for White Lily - Rs.550")
                print("Choose 10 for Pink Gerbera - Rs.550")
                print("*"*70)
                order = input("Enter your order:").split(',')
                print("Your ordered: ",order)
                print(f"Your selected order is:{list(map(us.selected_order,order))}")
                print("*"*70)
            elif op== "O":
                print(f"Order history:{list(map(us.selected_order,order))}")
                          
        elif choice == "U":
            print("Choose 1 for Name")
            print("Choose 2 for Phonenumber")
            print("Choose 3 for Email")
            print("Choose 4 for Address")
            print("Choose 5 for Password")
            print("*"*70)
            print(us.update_profile())
         
    elif option==3:
        print("Your order arrives earlier than you expected.")
        print("Thank you for ordering!")
        sys.exit()   
                
    else:
        print("OOPS! Please choose the valid option.")
# Out:
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:1
# ***************************Admin Login***************************
# Enter your username:admin
# Enter your password:admin
# Press 1 for Add New Bouquet
# Press 2 for View Bouquet List
# Press 3 for Edit Bouquet List
# Press 4 for Remove Bouquet List
# Enter your choice:1
# Bouquet Name:Rose
# Bouquet Size:large
# Bouquet Price:3000
# Bouquet Discount:10
# Bouquet Stock:4
# {16: {'Name': 'Rose', 'Size': 'large', 'Price': 3000, 'Discount': 10, 'Stock': 4}}
# Bouquet Name:Lily
# Bouquet Size:small
# Bouquet Price:4500
# Bouquet Discount:10
# Bouquet Stock:5
# {16: {'Name': 'Rose', 'Size': 'large', 'Price': 3000, 'Discount': 10, 'Stock': 4}, 9: {'Name': 'Lily', 'Size': 'small', 'Price': 4500, 'Discount': 10, 'Stock': 5}}
# Bouquet Name:Tulip
# Bouquet Size:medium
# Bouquet Price:3000
# Bouquet Discount:10
# Bouquet Stock:4
# {16: {'Name': 'Rose', 'Size': 'large', 'Price': 3000, 'Discount': 10, 'Stock': 4}, 9: {'Name': 'Lily', 'Size': 'small', 'Price': 4500, 'Discount': 10, 'Stock': 5}, 14: {'Name': 'Tulip', 'Size': 'medium', 'Price': 3000, 'Discount': 10, 'Stock': 4}}
# New Bouquet List Added Successfully!
# **********************************************************************
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:1
# ***************************Admin Login***************************
# Enter your username:admin
# Enter your password:admin
# Press 1 for Add New Bouquet
# Press 2 for View Bouquet List
# Press 3 for Edit Bouquet List
# Press 4 for Remove Bouquet List
# Enter your choice:2
# [16, {'Name': 'Rose', 'Size': 'large', 'Price': 3000, 'Discount': 10, 'Stock': 4}]
# [9, {'Name': 'Lily', 'Size': 'small', 'Price': 4500, 'Discount': 10, 'Stock': 5}]
# [14, {'Name': 'Tulip', 'Size': 'medium', 'Price': 3000, 'Discount': 10, 'Stock': 4}]
#
# You have viewed your bouquet list!
# **********************************************************************
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:1
# ***************************Admin Login***************************
# Enter your username:admin
# Enter your password:admin
# Press 1 for Add New Bouquet
# Press 2 for View Bouquet List
# Press 3 for Edit Bouquet List
# Press 4 for Remove Bouquet List
# Enter your choice:3
# Enter the id you want to edit:9
# Updated bouquet list: {16: {'Name': 'Rose', 'Size': 'large', 'Price': 3000, 'Discount': 10, 'Stock': 4}, 9: {'Name': 'Rose Vase', 'Size': 'Large', 'Price': '540', 'Discount': '20', 'Stock': '5'}, 14: {'Name': 'Tulip', 'Size': 'medium', 'Price': 3000, 'Discount': 10, 'Stock': 4}}
#
# You haved edited your bouquet list successfully!
# **********************************************************************
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:1
# ***************************Admin Login***************************
# Enter your username:admin
# Enter your password:admin
# Press 1 for Add New Bouquet
# Press 2 for View Bouquet List
# Press 3 for Edit Bouquet List
# Press 4 for Remove Bouquet List
# Enter your choice:4
# Enter the id you want to remove:14
# Remaining bouquet list: {16: {'Name': 'Rose', 'Size': 'large', 'Price': 3000, 'Discount': 10, 'Stock': 4}, 9: {'Name': 'Rose Vase', 'Size': 'Large', 'Price': '540', 'Discount': '20', 'Stock': '5'}}
#
# Bouquet List removed successfully!
# **********************************************************************
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:2
# ***************************User SignUp***************************
# Press R for Registration
# Press L for Login
# Press U for Update profile
# **********************************************************************
# Enter your choice:r
# Enter your full name:Brundha
# Enter your phonenumber:987654321
# Valid phone number.
# Enter your email:bru@gmail.com
# Valid email.
# Enter your address:111/1 main road.
# Create a new password using specified characters (eg:'AbcBe333') :bru30
# Valid Password
# {855: {'Fullname': 'Brundha', 'Phone Number': '987654321', 'Email': 'bru@gmail.com', 'Address': '111/1 main road.', 'Password': 'bru30'}}
# Registration Successfull!
# **********************************************************************
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:2
# ***************************User SignUp***************************
# Press R for Registration
# Press L for Login
# Press U for Update profile
# **********************************************************************
# Enter your choice:l
# Enter your email:bru@gmail.com
# Enter your password:bru30
# Welcome,Login Successfull!
# None
# Press P for Place New Order
# Press O for Order History
# **********************************************************************
# Choose your option:p
# Choose 1 for Orchid Hand Bunch - Rs.300
# Choose 2 for Roses - Rs.350
# Choose 3 for Bunch of mixed roses - Rs.375
# Choose 4 for Double Layered Gerbera - Rs.400
# Choose 5 for Yellow rose hunch - Rs.510
# Choose 6 for Rose vase - Rs.540
# Choose 7 for Roses and Gerberas - Rs.765
# Choose 8 for Red and yellow roses - Rs.1190
# Choose 9 for White Lily - Rs.550
# Choose 10 for Pink Gerbera - Rs.550
# **********************************************************************
# Enter your order:3,6,9
# Your ordered:  ['3', '6', '9']
# Your selected order is:['Bunch of mixed roses - Rs.375', 'Rose vase - Rs.540', 'White Lily - Rs.550']
# **********************************************************************
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:2
# ***************************User SignUp***************************
# Press R for Registration
# Press L for Login
# Press U for Update profile
# **********************************************************************
# Enter your choice:l
# Enter your email:bru@gmail.com
# Enter your password:bru30
# Welcome,Login Successfull!
# None
# Press P for Place New Order
# Press O for Order History
# **********************************************************************
# Choose your option:o
# Order history:['Bunch of mixed roses - Rs.375', 'Rose vase - Rs.540', 'White Lily - Rs.550']
# Press 1 for Admin Login
# Press 2 for User Login
# Press 3 for Exit
# Enter your option:3
# Your order arrives earlier than you expected.
# Thank you for ordering!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
